# %% [markdown]
# # TASK 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('SampleSuperstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df1 = pd.DataFrame(df.groupby(['Category'])[('Sales','Profit')].mean()).plot(kind='bar',figsize=(8,7))
# Out:
# <ipython-input-80-774131e002e7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = pd.DataFrame(df.groupby(['Category'])[('Sales','Profit')].mean()).plot(kind='bar',figsize=(8,7))

# %% [markdown]
# we can clearly see that that Technological good have highest amount of sale and even has a good Profit margine

# %%
df2 = pd.DataFrame(df.groupby(['Sub-Category'])[('Sales','Profit')].mean()).plot(kind='bar',figsize=(10,7))
# Out:
# <ipython-input-81-f4e5cdab7096>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = pd.DataFrame(df.groupby(['Sub-Category'])[('Sales','Profit')].mean()).plot(kind='bar',figsize=(10,7))

# %%
df2 = pd.DataFrame(df.groupby(['Sub-Category'])[('Profit')].mean()).plot(kind='bar',figsize=(10,7))

# %% [markdown]
# Copiers have the most sale and as the sale is good obviousily profit is also great
#
# Goods like Bookcases Supplies and Tables are incuring loss to the firm
#
# Paper, Accessories, Envelopes and Appliances have a good profit margine incompare to the total sale of those product

# %%
df2 = pd.DataFrame(df.groupby(['State'])[('Sales','Profit')].mean()).plot(kind='bar',figsize=(15,7))

df2 = pd.DataFrame(df.groupby(['State'])['Profit'].mean()).plot(kind='bar',figsize=(15,7))
# Out:
# <ipython-input-82-729a3d1bd4ca>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = pd.DataFrame(df.groupby(['State'])[('Sales','Profit')].mean()).plot(kind='bar',figsize=(15,7))

# %%
df2 = pd.DataFrame(df.groupby(['State'])[('Discount')].mean()).plot(kind='bar',figsize=(10,7))

# %% [markdown]
# States like Arizona, Colorado, Florida, Illinois, North Carolina, Ohio, Oregaon, Pennsylvania, Tennessee And texas are not performing good
#
# sales rate in Wyoming is Out of roof but the profit we incure is comparatively less but on the other hand states like Vermont,Delware,District of Columbia,Indiana,Minnesota have a healthy profit rates in front of sales they make

# %%
df2 = pd.DataFrame(df.groupby(['Segment'])[('Sales','Profit')].mean()).plot(kind='bar',figsize=(10,7))
# Out:
# <ipython-input-83-4ff57e00d2f7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = pd.DataFrame(df.groupby(['Segment'])[('Sales','Profit')].mean()).plot(kind='bar',figsize=(10,7))

# %% [markdown]
# We can see much variation in this chart but total sale of Home office Segment is slightly more and its profit is also a little more then other 2 Segments
#
# The consumer Segement gives Low profit in compare to other 2 Segments

# %%
plt.figure(figsize=(8,5))

plt.subplot(1,2,1)
sns.lineplot(x=df['Discount'],y=df['Sales'])

plt.subplot(1,2,2)
sns.lineplot(x=df['Discount'],y=df['Profit'])
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
df2 = pd.DataFrame(df.groupby(['Category'])[('Discount')].mean()).plot(kind='bar',figsize=(10,7))

# %% [markdown]
# As we increase the Discount our sales does increase but the profit margin decreases

# %% [markdown]
#    After detailed study of the data I think we can Increase profits in our business we can try to increase sale of Technological good as the profit we get by selling them is great. In Furniture good The profit is very less we can try to increase profit rate by decreasesing discount rates and try to get some profit.
#    On closer look we can see that products like Paper, Accessories, Envelopes and Appliances have a good profit in compare to the total sale of them so we can trying to increases their total sale in different state so the profit from these products will definately help us in increases overall profits of the firm
#    Fastners and Art have a very small amount of sale and we make no profits from it so we instead we can stop selling them and use the money we used to get fastners good in increasing our business in the products which are proven to give us more profits.
#    Now coming to sales and profit rates in different states Again we can see that the states where we are giving good discount are not making profit for the firm so we can reduce discount rates inorder to increase or we can balance it by giving a little more discount in the states where we make a good amount of profit and reduce discount in loss making state and try to reduce over total loss
